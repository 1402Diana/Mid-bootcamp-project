# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the DataFrame:
df = pd.read_excel(r'C:/Users/diana/OneDrive/Bureau/Labs/data_MID_bootcamp_PROJECT_regression/regression_data.xls')
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
# Standardize the header names:
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
# Rename the column "zipcode":
df = df.rename(columns={'zipcode': 'zip_code'})
df.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
# Check the datatype:
df_types=df.dtypes
df_types
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zip_code                  int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
# Change the datatype of some columns:
df['id'] = df['id'].astype('object')
df['waterfront'] = df['waterfront'].astype('object')
df['view'] = df['view'].astype('object')
df['condition'] = df['condition'].astype('object')
df['grade'] = df['grade'].astype('object')
df['yr_built'] = df['yr_built'].astype('object')
df['yr_renovated'] = df['yr_renovated'].astype('object')
df['zip_code'] = df['zip_code'].astype('object')
df.dtypes
# Out:
# id                       object
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront               object
# view                     object
# condition                object
# grade                    object
# sqft_above                int64
# sqft_basement             int64
# yr_built                 object
# yr_renovated             object
# zip_code                 object
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
# Extract the month from a date column and store in a separate column:
df['month'] = df['date'].dt.month
df = df.drop('date', axis=1)
df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21594  1523300141         2       0.75         1020      1350     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
# 21596  1523300157         2       0.75         1020      1076     2.0
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# Drop the dublicates:
df = df.drop_duplicates(keep='first')
df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21594  1523300141         2       0.75         1020      1350     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
# 21596  1523300157         2       0.75         1020      1076     2.0
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# Select the numerical data:
df_numerical=df.select_dtypes(include='number')
df_numerical
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0             3       1.00         1180      5650     1.0        1180
# 1             3       2.25         2570      7242     2.0        2170
# 2             2       1.00          770     10000     1.0         770
# 3             4       3.00         1960      5000     1.0        1050
# 4             3       2.00         1680      8080     1.0        1680
# ...         ...        ...          ...       ...     ...         ...
# 21592         3       2.50         1530      1131     3.0        1530
# 21593         4       2.50         2310      5813     2.0        2310
# 21594         2       0.75         1020      1350     2.0        1020
# 21595         3       2.50         1600      2388     2.0        1600
# 21596         2       0.75         1020      1076     2.0        1020
#
#        sqft_basement      lat     long  sqft_living15  sqft_lot15   price  \
# ...

# %%
# Check the Nan values:
df_nan=df_numerical.isna().sum()
df_nan
# Out:
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# sqft_above       0
# sqft_basement    0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# month            0
# dtype: int64

# %%
# Select the categorical data from DataFrame:
df_categorical=df.select_dtypes(exclude='number')
df_categorical
# Out:
#                id waterfront view condition grade yr_built yr_renovated  \
# 0      7129300520          0    0         3     7     1955            0
# 1      6414100192          0    0         3     7     1951         1991
# 2      5631500400          0    0         3     6     1933            0
# 3      2487200875          0    0         5     7     1965            0
# 4      1954400510          0    0         3     8     1987            0
# ...           ...        ...  ...       ...   ...      ...          ...
# 21592   263000018          0    0         3     8     2009            0
# 21593  6600060120          0    0         3     8     2014            0
# 21594  1523300141          0    0         3     7     2009            0
# 21595   291310100          0    0         3     8     2004            0
# 21596  1523300157          0    0         3     7     2008            0
#
#       zip_code
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
# ...

# %%
# Check the Nan values in the categorical data:
df_nan=df_categorical.isna().sum()
df_nan
# Out:
# id              0
# waterfront      0
# view            0
# condition       0
# grade           0
# yr_built        0
# yr_renovated    0
# zip_code        0
# dtype: int64

# %%
# Check the 'waterfront' column:
df["waterfront"].value_counts()
# Out:
# waterfront
# 0    21434
# 1      163
# Name: count, dtype: int64

# %%
# Check the 'view' column:
df["view"].value_counts()
# Out:
# view
# 0    19475
# 2      961
# 3      510
# 1      332
# 4      319
# Name: count, dtype: int64

# %%
# Check the 'condition' column:
df["condition"].value_counts()
# Out:
# condition
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: count, dtype: int64

# %%
# Check the 'grade' column:
df["grade"].value_counts()
# Out:
# grade
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: count, dtype: int64

# %%
# Summary statistics for numerical data in the DataFrame:
df_num=df_numerical
df_num.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21597.000000  21597.000000  21597.000000  2.159700e+04  21597.000000
# mean       3.373200      2.115826   2080.321850  1.509941e+04      1.494096
# std        0.926299      0.768984    918.106125  4.141264e+04      0.539683
# min        1.000000      0.500000    370.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1430.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.618000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068500e+04      2.000000
# max       33.000000      8.000000  13540.000000  1.651359e+06      3.500000
#
#          sqft_above  sqft_basement           lat          long  sqft_living15  \
# count  21597.000000   21597.000000  21597.000000  21597.000000   21597.000000
# mean    1788.596842     291.725008     47.560093   -122.213982    1986.620318
# ...

# %%
# Swap the rows with the columns:
summary=df_num.describe().T
summary
# Out:
#                  count           mean            std         min          25%  \
# bedrooms       21597.0       3.373200       0.926299      1.0000       3.0000
# bathrooms      21597.0       2.115826       0.768984      0.5000       1.7500
# sqft_living    21597.0    2080.321850     918.106125    370.0000    1430.0000
# sqft_lot       21597.0   15099.408760   41412.636876    520.0000    5040.0000
# floors         21597.0       1.494096       0.539683      1.0000       1.0000
# sqft_above     21597.0    1788.596842     827.759761    370.0000    1190.0000
# sqft_basement  21597.0     291.725008     442.667800      0.0000       0.0000
# lat            21597.0      47.560093       0.138552     47.1559      47.4711
# long           21597.0    -122.213982       0.140724   -122.5190    -122.3280
# sqft_living15  21597.0    1986.620318     685.230472    399.0000    1490.0000
# sqft_lot15     21597.0   12758.283512   27274.441950    651.0000    5100.0000
# ...

# %%
# Show the interquartile range for each numerical column:
summary['igr']=summary['75%']-summary['25%']
summary=summary.apply(lambda x: round(x,2))
summary
# Out:
#                  count       mean        std       min        25%        50%  \
# bedrooms       21597.0       3.37       0.93      1.00       3.00       3.00
# bathrooms      21597.0       2.12       0.77      0.50       1.75       2.25
# sqft_living    21597.0    2080.32     918.11    370.00    1430.00    1910.00
# sqft_lot       21597.0   15099.41   41412.64    520.00    5040.00    7618.00
# floors         21597.0       1.49       0.54      1.00       1.00       1.50
# sqft_above     21597.0    1788.60     827.76    370.00    1190.00    1560.00
# sqft_basement  21597.0     291.73     442.67      0.00       0.00       0.00
# lat            21597.0      47.56       0.14     47.16      47.47      47.57
# long           21597.0    -122.21       0.14   -122.52    -122.33    -122.23
# sqft_living15  21597.0    1986.62     685.23    399.00    1490.00    1840.00
# sqft_lot15     21597.0   12758.28   27274.44    651.00    5100.00    7620.00
# ...

# %%
# Visualize how price differ based on bedrooms:
sns.barplot(x=df["bedrooms"], y=df["price"])
plt.show()

# %%
# Check the 'bedrooms' column:
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
# Check the distribution on the numerical columns:
for col in df_numerical.columns:
  sns.distplot(df_numerical[col])
  plt.show()

# %%
# Check for outliers on the "target" ("price"):
sns.boxplot(df["price"])
# Out:
# <Axes: >

# %%
# To calculate the exact outliers range:
IQR = abs(np.quantile(df["price"], .25) - np.quantile(df["price"], .75)) * 1.5
lower_boundary = np.quantile(df["price"], .25) - IQR
upper_boundary = np.quantile(df["price"], .75) + IQR

# Outliers for this column are values smaller than lower_boundary or bigger than upper_boundary:
lower_boundary, upper_boundary
# Out:
# (-162500.0, 1129500.0)

# %%
# We can analyze outliers by using filters:
df[(df["price"] > 1129500) | (df["price"] < -162500)].sort_values("price")
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 3101   6613000015         4       3.00         3180      4649     2.0
# 7674   9286000150         6       4.00         5330     18116     2.0
# 2444   7856640560         5       3.50         3880     13885     2.0
# 13280  5015001215         4       3.50         3170      4000     2.0
# 1372   6117500320         3       2.25         2790     13791     1.0
# ...           ...       ...        ...          ...       ...     ...
# 1446   8907500070         5       5.00         8000     23985     2.0
# 4407   2470100110         5       5.75         9200     35069     2.0
# 9245   9208900037         6       7.75         9890     31374     2.0
# 3910   9808700762         5       4.50        10040     37325     2.0
# 7245   6762700020         6       8.00        12050     27600     2.5
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# For numerical features we have pearson / spearman correlation measure:
correlations_matrix = df_numerical.corr()

correlations_matrix["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# floors           0.256804
# sqft_lot         0.089876
# sqft_lot15       0.082845
# long             0.022036
# month           -0.009928
# Name: price, dtype: float64

# %%
# "sqft_living" has the highest correlation:
plt.scatter(df["price"], df["sqft_living"])

# %%
# Create a regression plot  to visualize the relationship between two variables: price and sqft_living:
sns.regplot(x=df["price"], y=df["sqft_living"])
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
# Analyse categorical data using a barplot.
# Visualize how price differ based  on the view of properties:
sns.barplot(x=df["view"], y=df["price"])
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
# Visualize how price differ based  on the condition of properties:
sns.barplot(x=df["condition"], y=df["price"])
plt.show()

# %%
# Visualize how price differ based on on whether a property is on the waterfront or not:
sns.barplot(x=df["waterfront"], y=df["price"])
plt.show()

# %%
# Visualize how price differ based  on the grade of properties:
sns.barplot(x=df["grade"], y=df["price"])
plt.show()

# %%
# Create a heatmap to visualize the correlation matrix of numerical variables in the dataset:
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
# Creates a copy of the original DataFrame:
df_final = df.copy()
df_final
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21594  1523300141         2       0.75         1020      1350     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
# 21596  1523300157         2       0.75         1020      1076     2.0
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# Remove the columns from the DataFrame
df1_final=df_final.drop(["zip_code", "yr_renovated", "yr_built","grade","view","id"], axis=1)

# %%
# Change all occurrences of True to 1 and False to 0 in the DataFrame:
df2_final = df1_final.replace({True: 1, False: 0})
df2_final
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0             3       1.00         1180      5650     1.0           0
# 1             3       2.25         2570      7242     2.0           0
# 2             2       1.00          770     10000     1.0           0
# 3             4       3.00         1960      5000     1.0           0
# 4             3       2.00         1680      8080     1.0           0
# ...         ...        ...          ...       ...     ...         ...
# 21592         3       2.50         1530      1131     3.0           0
# 21593         4       2.50         2310      5813     2.0           0
# 21594         2       0.75         1020      1350     2.0           0
# 21595         3       2.50         1600      2388     2.0           0
# 21596         2       0.75         1020      1076     2.0           0
#
#        condition  sqft_above  sqft_basement      lat     long  sqft_living15  \
# ...

# %%
# Create the binary columns for each category in the categorical column:
df2_final = pd.get_dummies(df2_final, drop_first=True)
df2_final
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0             3       1.00         1180      5650     1.0           0
# 1             3       2.25         2570      7242     2.0           0
# 2             2       1.00          770     10000     1.0           0
# 3             4       3.00         1960      5000     1.0           0
# 4             3       2.00         1680      8080     1.0           0
# ...         ...        ...          ...       ...     ...         ...
# 21592         3       2.50         1530      1131     3.0           0
# 21593         4       2.50         2310      5813     2.0           0
# 21594         2       0.75         1020      1350     2.0           0
# 21595         3       2.50         1600      2388     2.0           0
# 21596         2       0.75         1020      1076     2.0           0
#
#        condition  sqft_above  sqft_basement      lat     long  sqft_living15  \
# ...

# %%
# X-y split: here we keep only the data we will use to train the model
X = df2_final.drop(["bedrooms", "price"], axis=1)
y = df2_final["price"]

# Train-test split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train
# Out:
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  condition  \
# 753         2.50         2380      6600     1.0           0          3
# 1418        3.75         3190     17186     2.0           1          3
# 8178        2.50         1730      6930     2.0           0          3
# 2254        2.00         1870      8750     1.0           0          3
# 4063        3.00         2850     12714     1.0           0          3
# ...          ...          ...       ...     ...         ...        ...
# 11964       2.50         2230      5800     2.0           0          3
# 21575       2.75         2770      3852     2.0           0          3
# 5390        1.50         1530      9000     1.0           0          4
# 860         0.75          380     15000     1.0           0          3
# 15795       2.50         2755     11612     2.0           0          3
#
#        sqft_above  sqft_basement      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
# Start the scaler object:
scaler = StandardScaler()

# Fit the scaler object only on the training data to avoid data leakage:
scaler.fit(X_train)

# Transform training and the testing data:
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Start the model object:
lm = LinearRegression()

# Fit the model object on the training set:
lm.fit(X_train_scaled, y_train)

# Get predictions for the test set:
predictions = lm.predict(X_test_scaled)

# Calculate your metrics:
rmse = mean_squared_error(y_test, predictions, squared=False) # or mse with squared=True
mae = mean_absolute_error(y_test, predictions)
print("R2_score:", round(r2_score(y_test, predictions), 2))
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# R2_score: 0.63
# RMSE: 222832.98921942594
# MAE: 141616.6421258264

# %%
# Get the regression prot from the predictions vs the true values:
sns.regplot(x=y_test, y=predictions, line_kws={"color": "black"}, scatter_kws={"color": "grey"})
# Out:
# <Axes: xlabel='price'>

# %%
# Log scaling:
y_train_scaled = y_train.apply(lambda x: np.log(x) if x > 0 else 0)
y_test_scaled = y_test.apply(lambda x: np.log(x) if x > 0 else 0)
y_train_scaled
# Out:
# 753      13.458550
# 1418     14.346139
# 8178     12.460715
# 2254     12.409013
# 4063     12.829334
#            ...
# 11964    12.994530
# 21575    13.256894
# 5390     12.610871
# 860      12.409013
# 15795    13.208541
# Name: price, Length: 15117, dtype: float64

# %%
# Look at how log scaling changed the distribution:
sns.distplot(y_train_scaled, bins=10)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Compared to what we had before scaling:
sns.distplot(y_train, bins=10) # notice how the skew is reduced in the plot above
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Check the model:

lm = LinearRegression()
lm.fit(X_train_scaled, y_train_scaled)

predictions = lm.predict(X_test_scaled)
print("R2_score:", round(r2_score(y_test_scaled, predictions), 2))
# Out:
# R2_score: 0.7

# %%
sns.color_palette("colorblind")
sns.regplot(x=y_test_scaled, y=predictions)
# Out:
# <Axes: xlabel='price'>

# %%
result_df = X_test
result_df["price"] = y_test
result_df["scaled_price"] = y_test_scaled
result_df["error"] = abs(y_test_scaled - predictions)
result_df.sort_values("error", ascending=False)
# Out:
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  condition  \
# 326         2.50         3030     45004     2.0           0          3
# 18453       1.00          900      8580     1.0           0          3
# 18861       1.50         1910     21374     1.0           0          1
# 18318       1.00         1200      7000     2.0           0          1
# 13451       2.50         2640    432036     1.5           0          3
# ...          ...          ...       ...     ...         ...        ...
# 19498       2.50         2530      4229     2.0           0          3
# 12552       2.00         2090      4000     1.0           0          3
# 8818        2.75         3210     15939     2.0           0          3
# 15550       1.50          960      7400     1.0           0          3
# 20272       2.50         2692      8392     2.0           0          3
#
#        sqft_above  sqft_basement      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
sns.regplot(result_df, x='price', y='error')
# Out:
# <Axes: xlabel='price', ylabel='error'>

# %%
# Filter a DataFrame to exclude rows with a "PRICE" less than 1129500.
df_no_outliers = df_final[df_final["price"] < 1129500]
df_no_outliers
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21594  1523300141         2       0.75         1020      1350     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
# 21596  1523300157         2       0.75         1020      1076     2.0
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# Log scaling the numerical variables:
df_no_outliers[df_numerical.columns] = df_no_outliers[df_numerical.columns].applymap(lambda x: np.log(x) if x > 0 else 0) 
df_no_outliers
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0      7129300520  1.098612   0.000000     7.073270  8.639411  0.000000
# 1      6414100192  1.098612   0.810930     7.851661  8.887653  0.693147
# 2      5631500400  0.693147   0.000000     6.646391  9.210340  0.000000
# 3      2487200875  1.386294   1.098612     7.580700  8.517193  0.000000
# 4      1954400510  1.098612   0.693147     7.426549  8.997147  0.000000
# ...           ...       ...        ...          ...       ...       ...
# 21592   263000018  1.098612   0.916291     7.333023  7.030857  1.098612
# 21593  6600060120  1.386294   0.916291     7.745003  8.667852  0.693147
# 21594  1523300141  0.693147  -0.287682     6.927558  7.207860  0.693147
# 21595   291310100  1.098612   0.916291     7.377759  7.778211  0.693147
# 21596  1523300157  0.693147  -0.287682     6.927558  6.981006  0.693147
#
#       waterfront view condition grade  ...  sqft_basement  yr_built  \
# ...

# %%
# X-y split: here we keep only the data we will use to train the model
X = df_no_outliers.drop(["bedrooms", "price"], axis=1) 
y = df_no_outliers["price"]

# Train-test split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the model:
lm = LinearRegression()
lm.fit(X_train, y_train)

# Test the model:
predictions = lm.predict(X_test)
print("R2_score:", round(r2_score(y_test, predictions), 2)) # R2 has improved
# Out:
# R2_score: 0.72

# %%
sns.regplot(x=y_test, y=predictions)
# Out:
# <Axes: xlabel='price'>

# %%
# Since we scaled the target variable, we need to inverse transform to get the original values in the $ unit:
y_test_unscaled = y_test.apply(lambda x: np.exp(x))
predictions_unscaled = pd.Series(predictions).apply(lambda x: np.exp(x))

rmse = mean_squared_error(y_test_unscaled, predictions_unscaled, squared=False)
mae = mean_absolute_error(y_test_unscaled, predictions_unscaled)
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# RMSE: 116690.87737211236
# MAE: 85963.24689364736
